# %%
# !pip install jupyterlab pandas sqlalchemy psycopg2-binary matplotlib seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ----------------------- ---------------- 1.6/2.7 MB 13.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 12.1 MB/s eta 0:00:00
# ...
